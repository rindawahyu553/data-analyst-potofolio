# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

df_raw = pd.read_csv('dataset.csv')

print(f'Shape awal : {df_raw.shape}')
print(f'Kolom      : {df_raw.columns.tolist()}')
print()
df_raw.head(10)
# Out:
# Shape awal : (8807, 12)
# Kolom      : ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df_raw.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
print('MISSING VALUES')
missing = df_raw.isna().sum()
print(pd.DataFrame({'Jumlah Missing': missing}))

print(f'\n DATA DUPLIKAT')
print(f'Jumlah baris duplikat: {df_raw.duplicated().sum()}')

print(f'\n TITLE DENGAN #')
symbol = df_raw[df_raw['title'].str.startswith('#', na=False)]['title'].unique()
print(symbol)
# Out:
# MISSING VALUES
#               Jumlah Missing
# show_id                    0
# type                       0
# title                      0
# director                2634
# cast                     825
# country                  831
# date_added                10
# release_year               0
# rating                     4
# duration                   3
# listed_in                  0
# description                0
#
#  DATA DUPLIKAT
# Jumlah baris duplikat: 0
#
#  TITLE DENGAN #
# ['#Selfie' '#Selfie 69' '#Alive' '#AnneFrank - Parallel Stories'
#  '#FriendButMarried 2' '#FriendButMarried' '#blackAF' '#realityhigh'
#  '#Rucker50' '#cats_the_mewvie' '#Roxy']

# %%
# Hapus baris missing value
df = df.dropna(how='any').reset_index(drop=True)
print(f'Setelah drop NA     : {df.shape}')
# Out:
# Setelah drop NA     : (5296, 16)

# %%
# Bersihkan title
df['title'] = df['title'].str.lstrip('#').str.title()

# %%
df = df[df['date_added'] != 'April 1, 2020']

# %%
# Konversi kolom Tanggal ke format datetime
print('Tanggal sebelum:', df['date_added'].tolist())

df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce').dt.normalize()

# print('Tanggal sesudah:', df_fmt['Tanggal'].tolist())
print('Tipe data      :', df['date_added'].dtype)

# Ekstrak komponen tanggal
df['year']     = df['date_added'].dt.year
df['month']     = df['date_added'].dt.month
df['day']      = df['date_added'].dt.day
df['name_day'] = df['date_added'].dt.day_name()
df
# Out:
# Tanggal sebelum: [Timestamp('2021-09-24 00:00:00'), Timestamp('2021-09-24 00:00:00'), Timestamp('2021-09-24 00:00:00'), Timestamp('2021-09-23 00:00:00'), Timestamp('2021-09-21 00:00:00'), Timestamp('2021-09-20 00:00:00'), Timestamp('2021-09-19 00:00:00'), Timestamp('2021-09-19 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-15 00:00:00'), Timestamp('2021-09-14 00:00:00'), Timestamp('2021-09-10 00:00:
# ...

# %%
print('Tipe Data')
print(df.dtypes)
# Out:
# Tipe Data
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Tahun                  float64
# Bulan                  float64
# Hari                   float64
# Nama_Hari               object
# year                     int32
# month                    int32
# day                      int32
# name_day                object
# dtype: object

# %%
print('=== PERBANDINGAN SEBELUM VS SESUDAH ===')
print(f'Shape awal   : {df_raw.shape}')
print(f'Shape bersih : {df.shape}')
print(f'Baris dihapus: {df_raw.shape[0] - df.shape[0]}')
print()
print('=== PREVIEW DATASET BERSIH ===')
print(df)
# Out:
# === PERBANDINGAN SEBELUM VS SESUDAH ===
# Shape awal   : (8807, 12)
# Shape bersih : (5296, 20)
# Baris dihapus: 3511
#
# === PREVIEW DATASET BERSIH ===
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5291   s8802    Movie                        Zinzana      Majid Al Ansari
# 5292   s8803    Movie                         Zodiac        David Fincher
# 5293   s8805    Movie                     Zombieland      Ruben Fleischer
# 5294   s8806    Movie                           Zoom         Peter Hewitt
# ...
